# %%
! gdown https://drive.google.com/u/0/uc?id=17WpSslT1bv81vHy3k1u0lo53_S10evDe
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=17WpSslT1bv81vHy3k1u0lo53_S10evDe
# To: /content/CXR_Covid-19_Challenge.zip
# 3.61GB [00:55, 64.8MB/s]

# %%
! unzip -qq CXR_Covid-19_Challenge.zip

# %%
# ! gdown https://drive.google.com/u/2/uc?id=1cpqqgbb77-1vt5-SvmQWV2Klla_tuLjD

# %%
import glob
import cv2
import matplotlib.pyplot as plt

###########################
EPOCHS = 10
MODEL_NAME = 'VGG_16'
IMG_SIZE = '360x360'
OUTPUT_LAYERS = '128-32-3'
###########################

# %%
all_covid_files = glob.glob('/content/train/covid/*')
all_normal_files = glob.glob('/content/train/normal/*')
all_pneumo_files = glob.glob('/content/train/pneumonia/*')
print(len(all_covid_files)," ",len(all_normal_files)," ",len(all_pneumo_files)," ")
# Out:
# 6534   7151   4273

# %%
# plot it in histogram

# %%
plt.figure(figsize=(30,10))
img_covid = cv2.imread(all_covid_files[0])
plt.subplot(1,3,1)
plt.imshow(img_covid)
img_normal = cv2.imread(all_normal_files[0])
plt.subplot(1,3,2)
plt.imshow(img_normal)
img_pneumo = cv2.imread(all_pneumo_files[0])
plt.subplot(1,3,3)
plt.imshow(img_pneumo)
plt.show()

# %%
print(img_pneumo.shape)
print(img_covid.shape)
print(img_normal.shape)
# Out:
# (1024, 1024, 3)
# (512, 512, 3)
# (1024, 1024, 3)

# %%
plt.figure(figsize=(30,10))
img_covid = cv2.imread(all_covid_files[1])
plt.subplot(1,3,1)
plt.imshow(img_covid)
img_normal = cv2.imread(all_normal_files[1])
plt.subplot(1,3,2)
plt.imshow(img_normal)
img_pneumo = cv2.imread(all_pneumo_files[1])
plt.subplot(1,3,3)
plt.imshow(img_pneumo)
plt.show()

# %%
from tensorflow.keras.utils import to_categorical
from PIL import Image

import pandas as pd
import sys
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import numpy as np
import glob
import time
import cv2
import os
from tensorflow.keras.utils import to_categorical
from PIL import Image

import tensorflow as tf
from keras.regularizers import l2
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D,\
                                    GlobalMaxPool2D, Dropout, SpatialDropout2D, add, concatenate
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import AUC, Precision, Recall, SensitivityAtSpecificity, PrecisionAtRecall, \
                                     TruePositives, TrueNegatives, FalsePositives, FalseNegatives


from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow import keras

import pandas as pd

import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import numpy as np
import glob
import time
import cv2
import os

# %%
dir = glob.glob('train/*')
get_freq = {}
# count = 1
for item in dir:
  freq = len(glob.glob("{}/*".format(item)))
  print(freq)
  item_name  = item.split('/')[1]
  get_freq[item_name] = freq
  #get_freq[count] = freq
  #count += 1
  #get_freq.append(freq)
# Out:
# 4273
# 6534
# 7151

# %%
index = {'normal': 0, 'covid': 1,  'pneumonia': 2}
rev_index = {0: 'normal',1: 'covid', 2: 'pneumonia'}

# %%
def parse_filepath(filepath):
    try:
        #path, filename = os.path.split(filepath)
        label = filepath.split('/')[1]
        #filename, ext = os.path.splitext(filename)
        #label, _ = filename.split("_")
        return label
    except Exception as e:
        print('error to parse %s. %s' % (filepath, e))
        return None, None

# %%
# np.random.seed(42)

H, W, C = 360, 360, 3
N_LABELS = len(index)
D = 1

files_train = glob.glob("train/*/*.*")
print("Total files train = ",len(files_train))


# create a pandas data frame of images, age, gender and race
attributes = list(map(parse_filepath, files_train))

df_train = pd.DataFrame(attributes)
df_train['file'] = files_train
df_train.columns = ['label', 'file']
df_train = df_train.dropna()
df_train.tail()


p = np.random.permutation(len(df_train))
train_idx = p[:len(df_train)]
# Out:
# Total files train =  17958

# %%
# for item in files_train:
#     if item.split('.')[-1] not in 'jpg' and item.split('.')[-1] not in 'png':
#         print(item)
#     # print(item.split('.')[-1])
#     # break

# %%
##################################
H, W, C = 360, 360, 3
N_LABELS = len(index)
D = 1
##################################

files_validation = glob.glob("validation/*/*.*")
print("Total files valid = ",len(files_validation))

# create a pandas data frame of images, age, gender and race
attributes = list(map(parse_filepath, files_validation))

df_val = pd.DataFrame(attributes)
df_val['file'] = files_validation
df_val.columns = ['label', 'file']
df_val = df_val.dropna()
df_val.tail()

print(len(df_val))
p = np.random.permutation(len(df_val))
test_idx = p[:len(df_val)]
# Out:
# Total files valid =  3431
# 3431

# %%
print('train count: %s,  test count: %s' % (
    len(train_idx),  len(test_idx)))
# Out:
# train count: 17958,  test count: 3431

# %%
# for item in files_validation:
#     if item.split('.')[-1] not in 'jpg' and item.split('.')[-1] not in 'png':
#         print(item)
#     # print(item.split('.')[-1])
#     # break

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Flatten, GlobalAveragePooling2D


# Change the pretrained model name according to the given criteria

frozen = VGG16 (weights="imagenet", input_shape=(360,360,3), include_top=False)
frozen.summary()

trainable = frozen.output
trainable = GlobalAveragePooling2D()(trainable)
#print(trainable.shape)
trainable = Dense(128, activation="relu")(trainable)
trainable = Dense(32, activation="relu")(trainable)
trainable = Dense(N_LABELS, activation="softmax")(trainable)
model = Model(inputs=frozen.input, outputs=trainable)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 360, 360, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 360, 360, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 360, 360, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 180, 180, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 180, 180, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 180, 180, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 90, 90, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 90, 90, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 90, 90, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 90, 90, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 45, 45, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 45, 45, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 45, 45, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 45, 45, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 22, 22, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 22, 22, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 22, 22, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 22, 22, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 11, 11, 512)       0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 360, 360, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 360, 360, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 360, 360, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 180, 180, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 180, 180, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 180, 180, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 90, 90, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 90, 90, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 90, 90, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 90, 90, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 45, 45, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 45, 45, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 45, 45, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 45, 45, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 22, 22, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 22, 22, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 22, 22, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 22, 22, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 11, 11, 512)       0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 14,784,579
# Trainable params: 14,784,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
import keras
import keras.utils
from keras import utils as np_utils
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model

# Display

from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from tensorflow.keras.utils import to_categorical
from PIL import Image
import numpy as np
import cv2
import glob


"""
## The Grad-CAM algorithm
"""


def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        # print("shape = ", pred_index.shape)
        
        # print(pred_index)
        # plt.imshow(np.expand_dims(pred_index, axis=0))
        # print(preds.shape)
        class_channel = preds[:] 

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()
    
def get_jet_img(img, heatmap):
    

    # We rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # We use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # We use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # We create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * 0.4 + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    # save_path = "cell.jpg"
    # superimposed_img.save(save_path)
    # img_ = cv2.resize(img, (360, 360),interpolation=cv2.INTER_CUBIC)
    # print("img ","--"*60,img.shape)
    heatmap_ = cv2.resize(heatmap, (256, 256),interpolation = cv2.INTER_CUBIC)
    print("heatmap ","--"*60,heatmap.shape)
    print("heatmap_ ","--"*60,heatmap_.shape)
    superimposed_img_ = cv2.resize(np.array(superimposed_img), (256, 256),interpolation = cv2.INTER_CUBIC)
    print("superimposed img ","--"*60,np.array(superimposed_img).shape)
    # plt.show(superimposed_img)
    return img, heatmap, heatmap_, superimposed_img

# %%
# https://stackoverflow.com/questions/55640149/error-in-keras-when-i-want-to-calculate-the-sensitivity-and-specificity
# add specificity and sensitivity here
# https://datascience.stackexchange.com/questions/33587/keras-custom-loss-function-as-true-negatives-by-true-negatives-plus-false-posit/40746#40746
# add some loss functions here

# Metrics
# https://www.sabinasz.net/unbalanced-classes-machine-learning/

from keras import backend as K

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())



opt = Adam(learning_rate=1e-4)
model.compile(optimizer=opt, loss='categorical_crossentropy',
            #experimental_run_tf_function=False,
            metrics = ['accuracy', sensitivity, specificity]
            )

# %%
# tf.keras.utils.plot_model(model, to_file='Model1.png')
# from IPython.display import Image
# Image(retina=True, filename='Model1.png')

# %%
# data generator function needs to be changed, i.e., preprocessing should be done first
# to avoid bottlenecks.

from tensorflow.keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, labels = [], []
    while True:
        # print("indices = ",indices)    
        # print("len indices = ",len(indices))
        for i in indices:
            r = df.iloc[i]
            # print(" r = ", r, " i = ",i)
            file, label = r['file'], r['label']
            # print("file, label = ",file, label)
            im_gray = Image.open(file).convert('L')
            # print("Shape = ",im_gray.shape)
            im_gray = im_gray.resize((360,360))
            im = np.zeros(shape=(360,360,3))
            
            im[:,:,0] = im_gray
            im[:,:,1] = im_gray
            im[:,:,2] = im_gray
            im = np.array(im) / 255.0

            # print(im.shape)
            images.append(im)
            # print(np.asarray([to_categorical(index[label], N_LABELS)]))
            # print(np.asarray([to_categorical(index[label], N_LABELS)]).shape)
            
            labels.append(to_categorical(index[label], N_LABELS))
            if len(images) >= batch_size:
                yield np.array(images), np.array(labels)
                images, labels = [], []
        # if not for_training:
        #     break


from tensorflow.keras.utils import to_categorical
from PIL import Image

def get_data_generator_custom(df, indices, for_training, batch_size=16):
    labels = []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, label = r['file'], r['label']
            labels.append(to_categorical(index[label], N_LABELS))
            if len(images) >= batch_size:
                yield  np.array(labels)
                labels = []

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow import keras
# batch_size = 100
# valid_batch_size = 32
batch_size = 16
valid_batch_size = 16
train_gen = get_data_generator(df_train, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df_val, test_idx, for_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./model_checkpoint", monitor='val_loss'),
    #ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4)
]

# for storing logs into tensorboard
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# history = model.fit(train_gen,
#                     steps_per_epoch=len(train_idx)//batch_size,
#                     epochs=5,
#                     callbacks=[tensorboard_callback,callbacks],
#                     validation_data=valid_gen,
#                     validation_steps=len(test_idx)//valid_batch_size)

# %%
# ! gdown https://drive.google.com/u/2/uc?id=1Ma8-7fG8-CneFcR0qBJ2aXNakKXyujqS
! gdown https://drive.google.com/u/0/uc?id=1_fWrH3qvkYhA8Y0j7DRMEf_xroE8WJBh
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1_fWrH3qvkYhA8Y0j7DRMEf_xroE8WJBh
# To: /content/CXR_Covid-19_100e_VGG_16_360x360_128-32-3.h5
# 178MB [00:02, 86.6MB/s]

# %%
from tensorflow import keras
model = keras.models.load_model('CXR_Covid-19_100e_VGG_16_360x360_128-32-3.h5', custom_objects={'specificity': specificity, 'sensitivity': sensitivity})

# %%
test_gen = get_data_generator(df_val, test_idx, for_training=False)
dict(zip(model.metrics_names, model.evaluate(test_gen, steps=len(test_idx))))
# Out:
#   37/3431 [..............................] - ETA: 21:37 - loss: 0.7527 - accuracy: 0.9544 - sensitivity: 0.9544 - specificity: 0.9772
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-ee9ab59a0c02> in <module>()
#       1 test_gen = get_data_generator(df_val, test_idx, for_training=False)
# ----> 2 dict(zip(model.metrics_names, model.evaluate(test_gen, steps=len(test_idx))))
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1499             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1500               callbacks.on_test_batch_begin(step)
# -> 1501               tmp_logs = self.test_function(iterator)
#    1502               if data_handler.should_sync:
#    1503                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.utils import to_categorical
from PIL import Image
from tqdm import tqdm
y_pred_list = []
y_test_list = []

act_label_list = []
pred_label_list = []
list_file_name = []
all_pred = []

for i in tqdm(test_idx):
    r = df_val.iloc[i]
    file_, label = r['file'], r['label']
    

    im_gray = Image.open(file_).convert('L')
    # print("Shape = ",im_gray.shape)
    im_gray = im_gray.resize((360,360))
    im = np.zeros(shape=(360,360,3))

    im[:,:,0] = im_gray
    im[:,:,1] = im_gray
    im[:,:,2] = im_gray
    im = np.array(im) / 255.0


    # im = Image.open(file_)
    # im = im.resize((360, 360))
    # im = np.array(im) / 255.0
    # print(im[np.newaxis, ...].shape)
    y_pred = model.predict(im[np.newaxis, ...])
    y_pred_list.append(int(tf.math.argmax(y_pred, axis=-1)))
    histogram = y_pred
    all_pred.append(histogram)
    
    pred_label = rev_index[int(tf.math.argmax(y_pred, axis=-1))]
    act_label_list.append(label)
    pred_label_list.append(pred_label)
    list_file_name.append(file_)
    # if label == 'covid' and pred_label == 'covid':
    #     print('file = ',file_)
    #     print("Actual label = ",label)
    #     print("Histogram value = ",histogram)
    #     print("Predicted label = ",pred_label)
    #     break
    
    #     print("passed")
    
    #print(index[label])
    y_test_list.append(index[label])
    # print("This = ",rev_index[int(tf.math.argmax(y_pred, axis=-1))])
    # print(to_categorical(index[label], N_LABELS))
    # print(label)
# Out:
#  10%|█         | 352/3431 [00:48<06:44,  7.62it/s]Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f58ab9f9c20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
# 100%|██████████| 3431/3431 [08:31<00:00,  6.71it/s]

# %%
print(len(pred_label_list),len(act_label_list),len(list_file_name))
# Out:
# 3431 3431 3431

# %%
pred_label_list[:10]
# Out:
# ['covid',
#  'normal',
#  'pneumonia',
#  'pneumonia',
#  'covid',
#  'covid',
#  'normal',
#  'pneumonia',
#  'covid',
#  'covid']

# %%
act_label_list[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03962a7b80ac> in <module>()
# ----> 1 act_label_list[:10]
#
# NameError: name 'act_label_list' is not defined

# %%
list_file_name[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-56edeed2e5a6> in <module>()
# ----> 1 list_file_name[:10]
#
# NameError: name 'list_file_name' is not defined

# %%
all_pred[:10]
# Out:
# [array([[1.7165749e-26, 1.0000000e+00, 8.9233924e-20]], dtype=float32),
#  array([[1.0000000e+00, 3.0512141e-15, 1.3459565e-13]], dtype=float32),
#  array([[8.8418266e-14, 3.2136078e-12, 1.0000000e+00]], dtype=float32),
#  array([[3.0849126e-20, 5.2775759e-16, 1.0000000e+00]], dtype=float32),
#  array([[0., 1., 0.]], dtype=float32),
#  array([[2.8096562e-02, 9.7190338e-01, 9.8145581e-09]], dtype=float32),
#  array([[1.0000000e+00, 1.1503591e-18, 1.6608959e-14]], dtype=float32),
#  array([[3.8744768e-33, 1.6532849e-33, 1.0000000e+00]], dtype=float32),
#  array([[3.0599956e-06, 9.9999690e-01, 4.2674758e-10]], dtype=float32),
#  array([[7.046094e-21, 1.000000e+00, 3.202841e-14]], dtype=float32)]

# %%
c = 0

for pred, actual, list_name in zip(pred_label_list, act_label_list, list_file_name):
    if actual == 'covid' and pred == 'covid':
        try:
            c += 1
            print(list_name)
            file_name = list_name.split('.')[0]
            im_gray = Image.open(list_name).convert('L')
            im_gray = im_gray.resize((360,360))
            im = np.zeros(shape=(360,360,3))

            im[:,:,0] = im_gray
            im[:,:,1] = im_gray
            im[:,:,2] = im_gray
            im = np.array(im) / 255.0

            y_pred = model.predict(im[np.newaxis, ...])
            y_pred_list.append(int(tf.math.argmax(y_pred, axis=-1)))
            histogram = y_pred

            pred_label = rev_index[int(tf.math.argmax(y_pred, axis=-1))]

            # if label == 'normal' and pred_label == 'pneumonia':
            #     print('file = ',file_)
            #     print("Actual label = ",label)
            #     print("Histogram value = ",histogram)
            #     print("Predicted label = ",pred_label)
            #     break
            #print(index[label])
            y_test_list.append(index[label])
            heat_map = make_gradcam_heatmap(im[np.newaxis, ...], model, last_conv_layer_name, pred_index=None)
            im_gray_cv2 = cv2.imread(file_,cv2.IMREAD_GRAYSCALE)
            print(im_gray_cv2.shape)
            print(heat_map.shape)
            heat_map = heat_map/heat_map.max()
            # heat_map_save_name = file_name+"_"+last_conv_layer_name+"_heatmap"+".npy"
            # np.save(heat_map_save_name, heat_map)    # .npy extension is added if not given
            # heat_map = np.load(heat_map_save_name)

            # heat_map = heat_map.resize((im_gray_cv2.shape[0], im_gray_cv2.shape[1]))
            print(heat_map.shape)
            # save the heatmap
            plt.imshow(heat_map,cmap='hot')
            plt.show()

            inp = input("Save image = ? (y/N)")
            if inp == 'y' or inp == 'Y':
                print("Saved")
                heat_map_save_name = file_name+"_"+last_conv_layer_name+"_heatmap"+".npy"
                np.save(heat_map_save_name, heat_map)    # .npy extension is added if not given
        except:
            print("None")
# Out:
# validation/covid/cov_208.png
# None
# validation/covid/cov_642.png
# None
# validation/covid/cov_1251.png
# None
# validation/covid/cov_1069.png
# None
# validation/covid/cov_719.png
# None
# validation/covid/cov_1111.png
# None
# validation/covid/cov_593.png
# None
# validation/covid/cov_922.png
# None
# validation/covid/cov_820.png
# None
# validation/covid/cov_482.png
# None
# validation/covid/cov_111658.jpg
# None
# validation/covid/cov_359.png
# None
# validation/covid/cov_966.png
# None
# validation/covid/cov_995.png
# None
# validation/covid/cov_333.png
# None
# validation/covid/cov_111738.jpg
# None
# validation/covid/cov_935.png
# None
# validation/covid/cov_611.png
# None
# validation/covid/cov_687.png
# None
# validation/covid/cov_334.png
# None
# validation/covid/cov_777.png
# None
# validation/covid/cov_776.png
# None
# validation/covid/cov_168.png
# None
# validation/covid/cov_1195.png
# None
# validation/covid/cov_111726.jpg
# None
# validation/covid/cov_379.png
# None
# validation/covid/cov_111719.jpg
# None
# validation/covid/cov_111685.jpg
# None
# validation/covid/cov_850.png
# None
# validation/covid/cov_1189.png
# None
# validation/covid/cov_488.png
# None
# validation/covid/cov_1008.png
# None
# validation/covid/cov_512.png
# None
# validation/covid/cov_751.png
# None
# validation/covid/cov_111744.jpg
# None
# validation/covid/cov_630.png
# None
# validation/covid/cov_1194.png
# None
# validation/covid/cov_579.png
# None
# validation/covid/cov_986.png
# None
# validation/covid/cov_165.png
# None
# validation/covid/cov_274.png
# None
# validation/covid/cov_237.png
# None
# validation/covid/cov_552.png
# None
# validation/covid/cov_1059.png
# None
# validation/covid/cov_382.png
# None
# validation/covid/cov_1152.png
# None
# validation/covid/cov_934.png
# None
# validation/covid/cov_111723.jpg
# None
# validation/covid/cov_987.png
# None
# validation/covid/cov_1175.png
# None
# validation/covid/cov_1223.png
# None
# validation/covid/cov_478.png
# None
# validation/covid/cov_473.png
# None
# validation/covid/cov_92.png
# None
# validation/covid/cov_47.png
# None
# validation/covid/cov_417.png
# None
# validation/covid/cov_969.png
# None
# validation/covid/cov_1057.png
# None
# validation/covid/cov_819.png
# None
# validation/covid/cov_887.png
# None
# validation/covid/cov_550.png
# None
# validation/covid/cov_202.png
# None
# validation/covid/cov_327.png
# None
# validation/covid/cov_77.png
# None
# validation/covid/cov_111769.jpg
# None
# validation/covid/cov_111742.jpg
# None
# validation/covid/cov_316.png
# None
# validation/covid/cov_749.png
# None
# validation/covid/cov_489.png
# None
# validation/covid/cov_111670.jpg
# None
# validation/covid/cov_132.png
# None
# validation/covid/cov_616.png
# None
# validation/covid/cov_715.png
# None
# validation/covid/cov_143.png
# None
# validation/covid/cov_111693.jpg
# None
# validation/covid/cov_358.png
# None
# validation/covid/cov_1101.png
# None
# validation/covid/cov_469.png
# None
# validation/covid/cov_1177.png
# None
# validation/covid/cov_765.png
# None
# validation/covid/cov_475.png
# None
# validation/covid/cov_1157.png
# None
# validation/covid/cov_292.png
# None
# validation/covid/cov_131.png
# None
# validation/covid/cov_1198.png
# None
# validation/covid/cov_89.png
# None
# validation/covid/cov_308.png
# None
# validation/covid/cov_391.png
# None
# validation/covid/cov_957.png
# None
# validation/covid/cov_1226.png
# None
# validation/covid/cov_259.png
# None
# validation/covid/cov_1128.png
# None
# validation/covid/cov_605.png
# None
# validation/covid/cov_544.png
# None
# validation/covid/cov_428.png
# None
# validation/covid/cov_900.png
# None
# validation/covid/cov_111739.jpg
# None
# validation/covid/cov_445.png
# None
# validation/covid/cov_111753.jpg
# None
# validation/covid/cov_75.png
# None
# validation/covid/cov_111671.jpg
# None
# validation/covid/cov_416.png
# None
# validation/covid/cov_172.png
# None
# validation/covid/cov_716.png
# None
# validation/covid/cov_650.png
# None
# validation/covid/cov_1026.png
# None
# validation/covid/cov_683.png
# None
# validation/covid/cov_451.png
# None
# validation/covid/cov_174.png
# None
# validation/covid/cov_76.png
# None
# validation/covid/cov_905.png
# None
# validation/covid/cov_1087.png
# None
# validation/covid/cov_873.png
# None
# validation/covid/cov_901.png
# None
# validation/covid/cov_128.png
# None
# validation/covid/cov_111633.jpg
# None
# validation/covid/cov_763.png
# None
# validation/covid/cov_1190.png
# None
# validation/covid/cov_667.png
# None
# validation/covid/cov_890.png
# None
# validation/covid/cov_713.png
# None
# validation/covid/cov_870.png
# None
# validation/covid/cov_361.png
# None
# validation/covid/cov_124.png
# None
# validation/covid/cov_317.png
# None
# validation/covid/cov_67.png
# None
# validation/covid/cov_1129.png
# None
# validation/covid/cov_24.png
# None
# validation/covid/cov_111716.jpg
# None
# validation/covid/cov_260.png
# None
# validation/covid/cov_1248.png
# None
# validation/covid/cov_913.png
# None
# validation/covid/cov_1186.png
# None
# validation/covid/cov_111741.jpg
# None
# validation/covid/cov_153.png
# None
# validation/covid/cov_318.png
# None
# validation/covid/cov_111746.jpg
# None
# validation/covid/cov_1046.png
# None
# validation/covid/cov_281.png
# None
# validation/covid/cov_1219.png
# None
# validation/covid/cov_968.png
# None
# validation/covid/cov_111713.jpg
# None
# validation/covid/cov_789.png
# None
# validation/covid/cov_12.png
# None
# validation/covid/cov_305.png
# None
# validation/covid/cov_793.png
# None
# validation/covid/cov_1025.png
# None
# validation/covid/cov_931.png
# None
# validation/covid/cov_1148.png
# None
# validation/covid/cov_707.png
# None
# validation/covid/cov_989.png
# None
# validation/covid/cov_230.png
# None
# validation/covid/cov_111712.jpg
# None
# validation/covid/cov_745.png
# None
# validation/covid/cov_576.png
# None
# validation/covid/cov_964.png
# None
# validation/covid/cov_961.png
# None
# validation/covid/cov_111659.jpg
# None
# validation/covid/cov_113.png
# None
# validation/covid/cov_392.png
# None
# validation/covid/cov_946.png
# None
# validation/covid/cov_939.png
# None
# validation/covid/cov_280.png
# None
# validation/covid/cov_1239.png
# None
# validation/covid/cov_1065.png
# None
# validation/covid/cov_1230.png
# None
# validation/covid/cov_893.png
# None
# validation/covid/cov_1141.png
# None
# validation/covid/cov_433.png
# None
# validation/covid/cov_322.png
# None
# validation/covid/cov_111649.jpg
# None
# validation/covid/cov_111662.jpg
# None
# validation/covid/cov_111708.jpg
# None
# validation/covid/cov_620.png
# None
# validation/covid/cov_1126.png
# None
# validation/covid/cov_921.png
# None
# validation/covid/cov_494.png
# None
# validation/covid/cov_790.png
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f58ab9f9c20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
# None
# validation/covid/cov_568.png
# None
# validation/covid/cov_1050.png
# None
# validation/covid/cov_1238.png
# None
# validation/covid/cov_122.png
# None
# validation/covid/cov_649.png
# None
# validation/covid/cov_809.png
# None
# validation/covid/cov_133.png
# None
# validation/covid/cov_412.png
# None
# validation/covid/cov_655.png
# None
# validation/covid/cov_711.png
# None
# validation/covid/cov_306.png
# None
# validation/covid/cov_328.png
# None
# validation/covid/cov_273.png
# None
# validation/covid/cov_396.png
# None
# validation/covid/cov_527.png
# None
# validation/covid/cov_602.png
# None
# validation/covid/cov_65.png
# None
# validation/covid/cov_827.png
# None
# validation/covid/cov_351.png
# None
# validation/covid/cov_111764.jpg
# None
# validation/covid/cov_638.png
# None
# validation/covid/cov_510.png
# None
# validation/covid/cov_107.png
# None
# validation/covid/cov_111762.jpg
# None
# validation/covid/cov_537.png
# None
# validation/covid/cov_111758.jpg
# None
# validation/covid/cov_111729.jpg
# None
# validation/covid/cov_335.png
# None
# validation/covid/cov_841.png
# None
# validation/covid/cov_591.png
# None
# validation/covid/cov_632.png
# None
# validation/covid/cov_822.png
# None
# validation/covid/cov_803.png
# None
# validation/covid/cov_87.png
# None
# validation/covid/cov_111763.jpg
# None
# validation/covid/cov_1146.png
# None
# validation/covid/cov_302.png
# None
# validation/covid/cov_167.png
# None
# validation/covid/cov_135.png
# None
# validation/covid/cov_1010.png
# None
# validation/covid/cov_828.png
# None
# validation/covid/cov_262.png
# None
# validation/covid/cov_444.png
# None
# validation/covid/cov_341.png
# None
# validation/covid/cov_1135.png
# None
# validation/covid/cov_739.png
# None
# validation/covid/cov_797.png
# None
# validation/covid/cov_111617.jpg
# None
# validation/covid/cov_429.png
# None
# validation/covid/cov_1192.png
# None
# validation/covid/cov_517.png
# None
# validation/covid/cov_1044.png
# None
# validation/covid/cov_1212.png
# None
# validation/covid/cov_1005.png
# None
# validation/covid/cov_227.png
# None
# validation/covid/cov_111691.jpg
# None
# validation/covid/cov_1006.png
# None
# validation/covid/cov_662.png
# None
# validation/covid/cov_501.png
# None
# validation/covid/cov_528.png
# None
# validation/covid/cov_349.png
# None
# validation/covid/cov_784.png
# None
# validation/covid/cov_705.png
# None
# validation/covid/cov_344.png
# None
# validation/covid/cov_357.png
# None
# validation/covid/cov_906.png
# None
# validation/covid/cov_918.png
# None
# validation/covid/cov_741.png
# None
# validation/covid/cov_1258.png
# None
# validation/covid/cov_1031.png
# None
# validation/covid/cov_721.png
# None
# validation/covid/cov_1180.png
# None
# validation/covid/cov_1012.png
# None
# validation/covid/cov_1049.png
# None
# validation/covid/cov_567.png
# None
# validation/covid/cov_283.png
# None
# validation/covid/cov_394.png
# None
# validation/covid/cov_1033.png
# None
# validation/covid/cov_79.png
# None
# validation/covid/cov_8.png
# None
# validation/covid/cov_851.png
# None
# validation/covid/cov_628.png
# None
# validation/covid/cov_889.png
# None
# validation/covid/cov_111627.jpg
# None
# validation/covid/cov_836.png
# None
# validation/covid/cov_370.png
# None
# validation/covid/cov_570.png
# None
# validation/covid/cov_213.png
# None
# validation/covid/cov_111696.jpg
# None
# validation/covid/cov_613.png
# None
# validation/covid/cov_603.png
# None
# validation/covid/cov_618.png
# None
# validation/covid/cov_1187.png
# None
# validation/covid/cov_1145.png
# None
# validation/covid/cov_1257.png
# None
# validation/covid/cov_1061.png
# None
# validation/covid/cov_111622.jpg
# None
# validation/covid/cov_270.png
# None
# validation/covid/cov_407.png
# None
# validation/covid/cov_177.png
# None
# validation/covid/cov_401.png
# None
# validation/covid/cov_111611.jpg
# None
# validation/covid/cov_1042.png
# None
# validation/covid/cov_859.png
# None
# validation/covid/cov_1027.png
# None
# validation/covid/cov_15.png
# None
# validation/covid/cov_759.png
# None
# validation/covid/cov_1017.png
# None
# validation/covid/cov_164.png
# None
# validation/covid/cov_666.png
# None
# validation/covid/cov_659.png
# None
# validation/covid/cov_717.png
# None
# validation/covid/cov_1171.png
# None
# validation/covid/cov_63.png
# None
# validation/covid/cov_1150.png
# None
# validation/covid/cov_796.png
# None
# validation/covid/cov_862.png
# None
# validation/covid/cov_1089.png
# None
# validation/covid/cov_714.png
# None
# validation/covid/cov_472.png
# None
# validation/covid/cov_694.png
# None
# validation/covid/cov_320.png
# None
# validation/covid/cov_258.png
# None
# validation/covid/cov_18.png
# None
# validation/covid/cov_378.png
# None
# validation/covid/cov_1138.png
# None
# validation/covid/cov_965.png
# None
# validation/covid/cov_111759.jpg
# None
# validation/covid/cov_0.png
# None
# validation/covid/cov_275.png
# None
# validation/covid/cov_53.png
# None
# validation/covid/cov_73.png
# None
# validation/covid/cov_876.png
# None
# validation/covid/cov_3.png
# None
# validation/covid/cov_624.png
# None
# validation/covid/cov_878.png
# None
# validation/covid/cov_587.png
# None
# validation/covid/cov_78.png
# None
# validation/covid/cov_574.png
# None
# validation/covid/cov_938.png
# None
# validation/covid/cov_293.png
# None
# validation/covid/cov_838.png
# None
# validation/covid/cov_871.png
# None
# validation/covid/cov_399.png
# None
# validation/covid/cov_377.png
# None
# validation/covid/cov_1233.png
# None
# validation/covid/cov_57.png
# None
# validation/covid/cov_581.png
# None
# validation/covid/cov_483.png
# None
# validation/covid/cov_555.png
# None
# validation/covid/cov_1241.png
# None
# validation/covid/cov_592.png
# None
# validation/covid/cov_111704.jpg
# None
# validation/covid/cov_1202.png
# None
# validation/covid/cov_261.png
# None
# validation/covid/cov_4.png
# None
# validation/covid/cov_1036.png
# None
# validation/covid/cov_375.png
# None
# validation/covid/cov_289.png
# None
# validation/covid/cov_844.png
# None
# validation/covid/cov_286.png
# None
# validation/covid/cov_1142.png
# None
# validation/covid/cov_160.png
# None
# validation/covid/cov_879.png
# None
# validation/covid/cov_858.png
# None
# validation/covid/cov_877.png
# None
# validation/covid/cov_1240.png
# None
# validation/covid/cov_182.png
# None
# validation/covid/cov_139.png
# None
# validation/covid/cov_571.png
# None
# validation/covid/cov_697.png
# None
# validation/covid/cov_220.png
# None
# validation/covid/cov_805.png
# None
# validation/covid/cov_441.png
# None
# validation/covid/cov_584.png
# None
# validation/covid/cov_111766.jpg
# None
# validation/covid/cov_176.png
# None
# validation/covid/cov_807.png
# None
# validation/covid/cov_782.png
# None
# validation/covid/cov_816.png
# None
# validation/covid/cov_1115.png
# None
# validation/covid/cov_1015.png
# None
# validation/covid/cov_942.png
# None
# validation/covid/cov_1163.png
# None
# validation/covid/cov_1263.png
# None
# validation/covid/cov_111650.jpg
# None
# validation/covid/cov_296.png
# None
# validation/covid/cov_534.png
# None
# validation/covid/cov_1155.png
# None
# validation/covid/cov_157.png
# None
# validation/covid/cov_179.png
# None
# validation/covid/cov_1172.png
# None
# validation/covid/cov_653.png
# None
# validation/covid/cov_514.png
# None
# validation/covid/cov_111687.jpg
# None
# validation/covid/cov_111720.jpg
# None
# validation/covid/cov_988.png
# None
# validation/covid/cov_99.png
# None
# validation/covid/cov_678.png
# None
# validation/covid/cov_263.png
# None
# validation/covid/cov_1117.png
# None
# validation/covid/cov_907.png
# None
# validation/covid/cov_111661.jpg
# None
# validation/covid/cov_558.png
# None
# validation/covid/cov_26.png
# None
# validation/covid/cov_677.png
# None
# validation/covid/cov_83.png
# None
# validation/covid/cov_823.png
# None
# validation/covid/cov_2.png
# None
# validation/covid/cov_39.png
# None
# validation/covid/cov_595.png
# None
# validation/covid/cov_1051.png
# None
# validation/covid/cov_163.png
# None
# validation/covid/cov_467.png
# None
# validation/covid/cov_247.png
# None
# validation/covid/cov_40.png
# None
# validation/covid/cov_383.png
# None
# validation/covid/cov_1110.png
# None
# validation/covid/cov_546.png
# None
# validation/covid/cov_455.png
# None
# validation/covid/cov_860.png
# None
# validation/covid/cov_447.png
# None
# validation/covid/cov_764.png
# None
# validation/covid/cov_636.png
# None
# validation/covid/cov_752.png
# None
# validation/covid/cov_462.png
# None
# validation/covid/cov_1002.png
# None
# validation/covid/cov_474.png
# None
# validation/covid/cov_507.png
# None
# validation/covid/cov_1220.png
# None
# validation/covid/cov_226.png
# None
# validation/covid/cov_664.png
# None
# validation/covid/cov_861.png
# None
# validation/covid/cov_637.png
# None
# validation/covid/cov_1039.png
# None
# validation/covid/cov_490.png
# None
# validation/covid/cov_436.png
# None
# validation/covid/cov_1088.png
# None
# validation/covid/cov_155.png
# None
# validation/covid/cov_1260.png
# None
# validation/covid/cov_692.png
# None
# validation/covid/cov_365.png
# None
# validation/covid/cov_294.png
# None
# validation/covid/cov_1071.png
# None
# validation/covid/cov_1127.png
# None
# validation/covid/cov_788.png
# None
# validation/covid/cov_1099.png
# None
# validation/covid/cov_758.png
# None
# validation/covid/cov_111752.jpg
# None
# validation/covid/cov_46.png
# None
# validation/covid/cov_832.png
# None
# validation/covid/cov_864.png
# None
# validation/covid/cov_923.png
# None
# validation/covid/cov_791.png
# None
# validation/covid/cov_1120.png
# None
# validation/covid/cov_885.png
# None
# validation/covid/cov_971.png
# None
# validation/covid/cov_276.png
# None
# validation/covid/cov_454.png
# None
# validation/covid/cov_962.png
# None
# validation/covid/cov_675.png
# None
# validation/covid/cov_1176.png
# None
# validation/covid/cov_1014.png
# None
# validation/covid/cov_484.png
# None
# validation/covid/cov_617.png
# None
# validation/covid/cov_111722.jpg
# None
# validation/covid/cov_1224.png
# None
# validation/covid/cov_448.png
# None
# validation/covid/cov_804.png
# None
# validation/covid/cov_487.png
# None
# validation/covid/cov_1118.png
# None
# validation/covid/cov_849.png
# None
# validation/covid/cov_23.png
# None
# validation/covid/cov_1245.png
# None
# validation/covid/cov_363.png
# None
# validation/covid/cov_257.png
# None
# validation/covid/cov_492.png
# None
# validation/covid/cov_111672.jpg
# None
# validation/covid/cov_56.png
# None
# validation/covid/cov_111616.jpg
# None
# validation/covid/cov_927.png
# None
# validation/covid/cov_111731.jpg
# None
# validation/covid/cov_111767.jpg
# None
# validation/covid/cov_1252.png
# None
# validation/covid/cov_111711.jpg
# None
# validation/covid/cov_406.png
# None
# validation/covid/cov_564.png
# None
# validation/covid/cov_627.png
# None
# validation/covid/cov_303.png
# None
# validation/covid/cov_181.png
# None
# validation/covid/cov_1074.png
# None
# validation/covid/cov_601.png
# None
# validation/covid/cov_364.png
# None
# validation/covid/cov_977.png
# None
# validation/covid/cov_491.png
# None
# validation/covid/cov_55.png
# None
# validation/covid/cov_575.png
# None
# validation/covid/cov_614.png
# None
# validation/covid/cov_506.png
# None
# validation/covid/cov_604.png
# None
# validation/covid/cov_773.png
# None
# validation/covid/cov_121.png
# None
# validation/covid/cov_1124.png
# None
# validation/covid/cov_111700.jpg
# None
# validation/covid/cov_313.png
# None
# validation/covid/cov_111690.jpg
# None
# validation/covid/cov_556.png
# None
# validation/covid/cov_1011.png
# None
# validation/covid/cov_84.png
# None
# validation/covid/cov_236.png
# None
# validation/covid/cov_1116.png
# None
# validation/covid/cov_298.png
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f58ab9f9c20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
# None
# validation/covid/cov_505.png
# None
# validation/covid/cov_676.png
# None
# validation/covid/cov_437.png
# None
# validation/covid/cov_626.png
# None
# validation/covid/cov_48.png
# None
# validation/covid/cov_111630.jpg
# None
# validation/covid/cov_111721.jpg
# None
# validation/covid/cov_725.png
# None
# validation/covid/cov_111745.jpg
# None
# validation/covid/cov_542.png
# None
# validation/covid/cov_69.png
# None
# validation/covid/cov_926.png
# None
# validation/covid/cov_196.png
# None
# validation/covid/cov_1080.png
# None
# validation/covid/cov_123.png
# None
# validation/covid/cov_325.png
# None
# validation/covid/cov_1134.png
# None
# validation/covid/cov_1121.png
# None
# validation/covid/cov_883.png
# None
# validation/covid/cov_500.png
# None
# validation/covid/cov_118.png

# %%
! mv validation/covid/cov_1111.png .
! mv validation/covid/cov_593.png . 
! mv validation/covid/cov_922.png .
! mv validation/covid/cov_820.png .
! mv validation/covid/cov_482.png .
! mv validation/covid/cov_111658.jpg .
! mv validation/covid/cov_359.png .
! mv validation/covid/cov_966.png .
! mv validation/covid/cov_995.png .
! mv validation/covid/cov_333.png .
! mv validation/covid/cov_111738.jpg .

# %%
! mv validation/covid/cov_25.png .

# %%
make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None)

# %%
all_files = glob.glob('*.png')
all_files
# Out:
# ['cov_1111.png',
#  'cov_593.png',
#  'cov_482.png',
#  'cov_995.png',
#  'cov_333.png',
#  'cov_1251.png',
#  'cov_966.png',
#  'cov_922.png',
#  'cov_820.png',
#  'cov_359.png']

# %%
# block1_conv1 (3, 3, 3, 64)
# block1_conv2 (3, 3, 64, 64)
# block2_conv1 (3, 3, 64, 128)
# block2_conv2 (3, 3, 128, 128)
# block3_conv1 (3, 3, 128, 256)
# block3_conv2 (3, 3, 256, 256)
# block3_conv3 (3, 3, 256, 256)
# block4_conv1 (3, 3, 256, 512)
# block4_conv2 (3, 3, 512, 512)
# block4_conv3 (3, 3, 512, 512)
# block5_conv1 (3, 3, 512, 512)
# block5_conv2 (3, 3, 512, 512)
# block5_conv3 (3, 3, 512, 512)

# %%
last_conv_layer_name = 'block4_conv3'



for file_ in all_files:
    file_name = file_.split('.')[0]
    im_gray = Image.open(file_).convert('L')
    im_gray = im_gray.resize((360,360))
    im = np.zeros(shape=(360,360,3))

    im[:,:,0] = im_gray
    im[:,:,1] = im_gray
    im[:,:,2] = im_gray
    im = np.array(im) / 255.0

    y_pred = model.predict(im[np.newaxis, ...])
    y_pred_list.append(int(tf.math.argmax(y_pred, axis=-1)))
    histogram = y_pred

    pred_label = rev_index[int(tf.math.argmax(y_pred, axis=-1))]

    # if label == 'normal' and pred_label == 'pneumonia':
    #     print('file = ',file_)
    #     print("Actual label = ",label)
    #     print("Histogram value = ",histogram)
    #     print("Predicted label = ",pred_label)
    #     break
    #print(index[label])
    y_test_list.append(index[label])
    heat_map = make_gradcam_heatmap(im[np.newaxis, ...], model, last_conv_layer_name, pred_index=None)
    im_gray_cv2 = cv2.imread(file_,cv2.IMREAD_GRAYSCALE)
    print(im_gray_cv2.shape)
    print(heat_map.shape)
    heat_map = heat_map/heat_map.max()
    # heat_map_save_name = file_name+"_"+last_conv_layer_name+"_heatmap"+".npy"
    # np.save(heat_map_save_name, heat_map)    # .npy extension is added if not given
    # heat_map = np.load(heat_map_save_name)

    # heat_map = heat_map.resize((im_gray_cv2.shape[0], im_gray_cv2.shape[1]))
    print(heat_map.shape)
    # save the heatmap
    plt.imshow(heat_map,cmap='hot')
    plt.show()

    inp = input("Save image = ? (y/N)")
    if inp == 'y' or inp == 'Y':
        print("Saved")
        heat_map_save_name = file_name+"_"+last_conv_layer_name+"_heatmap"+".npy"
        np.save(heat_map_save_name, heat_map)    # .npy extension is added if not given
    # merged_img = heat_map + img_gray_cv2
    # plt.imshow(merged_img)
    # plt.show()
    # break
# Out:
# (512, 512)
# (45, 45)
# (45, 45)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Save image = ? (y/N)N
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)N
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)y
# Saved
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n
# (512, 512)
# (45, 45)
# (45, 45)
# Save image = ? (y/N)n

# %%
! mkdir npy_files

# %%
! mv *.npy npy_files

# %%
! zip -r npy_files.zip npy_files
# Out:
#   adding: npy_files/ (stored 0%)
#   adding: npy_files/norml_581_block2_conv1_heatmap.npy (deflated 14%)
#   adding: npy_files/norml_581_block5_conv2_heatmap.npy (deflated 75%)
#   adding: npy_files/pneu_423_block1_conv1_heatmap.npy (deflated 47%)
#   adding: npy_files/pneu_423_block5_conv3_heatmap.npy (deflated 86%)
#   adding: npy_files/pneu_423_block5_conv1_heatmap.npy (deflated 43%)
#   adding: npy_files/pneu_431_block5_conv1_heatmap.npy (deflated 96%)
#   adding: npy_files/norml_581_block1_conv1_heatmap.npy (deflated 72%)
#   adding: npy_files/pneu_423_block4_conv1_heatmap.npy (deflated 19%)
#   adding: npy_files/norml_922_block4_conv3_heatmap.npy (deflated 78%)
#   adding: npy_files/norml_922_block4_conv2_heatmap.npy (deflated 92%)
#   adding: npy_files/pneu_423_block2_conv1_heatmap.npy (deflated 83%)
#   adding: npy_files/norml_922_block5_conv1_heatmap.npy (deflated 88%)
#   adding: npy_files/pneu_423_block3_conv2_heatmap.npy (deflated 26%)
#   adding: npy_files/norml_581_block5_conv3_heatmap.npy (deflated 75%)
#   adding: npy_files/norml_581_block3_conv3_heatmap.npy (deflated 14%)
#   adding: npy_files/norml_581_block5_conv1_heatmap.npy (deflated 48%)
#   adding: npy_files/norml_922_block3_conv2_heatmap.npy (deflated 50%)
#   adding: npy_files/norml_922_block5_conv3_heatmap.npy (deflated 34%)
#   adding: npy_files/norml_581_block4_conv1_heatmap.npy (deflated 19%)
#   adding: npy_files/norml_922_block1_conv1_heatmap.npy (deflated 59%)
#   adding: npy_files/pneu_423_block5_conv2_heatmap.npy (deflated 43%)
#   adding: npy_files/pneu_423_block4_conv3_heatmap.npy (deflated 34%)
#   adding: npy_files/norml_922_block5_conv2_heatmap.npy (deflated 71%)
#   adding: npy_files/norml_581_block3_conv2_heatmap.npy (deflated 11%)
#   adding: npy_files/pneu_423_block3_conv3_heatmap.npy (deflated 50%)
#   adding: npy_files/norml_581_block3_conv1_heatmap.npy (deflated 13%)
#   adding: npy_files/norml_581_block4_conv3_heatmap.npy (deflated 57%)
#   adding: npy_files/norml_922_block3_conv3_heatmap.npy (deflated 71%)
#   adding: npy_files/pneu_423_block4_conv2_heatmap.npy (deflated 16%)
#   adding: npy_files/norml_922_block3_conv1_heatmap.npy (deflated 49%)
#   adding: npy_files/norml_581_block4_conv2_heatmap.npy (deflated 22%)
#   adding: npy_files/norml_922_block2_conv1_heatmap.npy (deflated 79%)
#   adding: npy_files/pneu_423_block3_conv1_heatmap.npy (deflated 51%)
