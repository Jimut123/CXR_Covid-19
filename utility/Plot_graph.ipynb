# %%
! ls
# Out:
# CHEST_dice_coef.eps			  history_orunet_chest_fold_1.json
# CHEST_loss.eps				  history_r2unet_chest_fold_1.json
# CHEST_precision.eps			  history_Unet_chest_fold_1.json
# CHEST_recall.eps			  LUNGS_accuracy_coef.eps
# history_attnR2Unet_chest_fold_1.json	  LUNGS_jacard.eps
# history_attnUnet_chest_fold_1.json	  LUNGS_jacard.png
# history_drrmsan_chest_fold_1.json	  Plot_CHEST_All.ipynb
# history_multi_res_unet_chest_fold_1.json

# %%
import json
import matplotlib.pyplot as plt
with open('history_attnR2Unet_chest_fold_1.json', 'r') as f:
    attnR2Unet = json.load(f)
print (len(attnR2Unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_r2unet_chest_fold_1.json', 'r') as f:
    r2unet = json.load(f)
print (len(r2unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_attnUnet_chest_fold_1.json', 'r') as f:
    attn_unet = json.load(f)
print (len(attn_unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_multi_res_unet_chest_fold_1.json', 'r') as f:
    multi_res_unet = json.load(f)
print (len(multi_res_unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_Unet_chest_fold_1.json', 'r') as f:
    UNet = json.load(f)
print (len(UNet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_orunet_chest_fold_1.json', 'r') as f:
    orunet = json.load(f)
print (len(orunet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_drrmsan_chest_fold_5.json', 'r') as f:
    drrmsan_ms = json.load(f)
print (len(drrmsan_ms))
# Out:
# 31

# %%
for item in drrmsan_ms:
    print(item)
# Out:
# loss
# side_6_loss
# side_7_loss
# side_8_loss
# activation_584_loss
# add_179_loss
# side_6_dice_coef
# side_6_jacard
# side_6_recall_4
# side_6_precision_4
# side_6_accuracy
# side_7_dice_coef
# side_7_jacard
# side_7_recall_4
# side_7_precision_4
# side_7_accuracy
# side_8_dice_coef
# side_8_jacard
# side_8_recall_4
# side_8_precision_4
# side_8_accuracy
# activation_584_dice_coef
# activation_584_jacard
# activation_584_recall_4
# activation_584_precision_4
# activation_584_accuracy
# add_179_dice_coef
# add_179_jacard
# add_179_recall_4
# add_179_precision_4
# add_179_accuracy

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

accuracy_attnR2Unet = []
for item in attnR2Unet['accuracy']:
    accuracy_attnR2Unet.append(attnR2Unet['accuracy'][item])

accuracy_r2unet = []
for item in r2unet['accuracy']:
    accuracy_r2unet.append(r2unet['accuracy'][item])

accuracy_attn_unet = []
for item in attn_unet['accuracy']:
    accuracy_attn_unet.append(attn_unet['accuracy'][item])

accuracy_multi_res_unet = []
for item in multi_res_unet['accuracy']:
    accuracy_multi_res_unet.append(multi_res_unet['accuracy'][item])

accuracy_UNet = []
for item in UNet['accuracy']:
    accuracy_UNet.append(UNet['accuracy'][item])
    
accuracy_orunet = []
for item in orunet['accuracy']:
    accuracy_orunet.append(orunet['accuracy'][item])
    
# accuracy_attn_1_proposed = []
# for item in attn_1_proposed['accuracy']:
#     accuracy_attn_1_proposed.append(attn_1_proposed['accuracy'][item])

accuracy_ms_proposed = []
for item in drrmsan_ms['activation_116_accuracy']:
    accuracy_ms_proposed.append(drrmsan_ms['activation_116_accuracy'][item])

plt.figure(figsize=(12,6))
plt.title('Accuracy for CHEST dataset', fontsize=35, fontname = 'DejaVu Serif', fontweight = 500)
#plt.plot(accuracy_attnR2Unet,color='green')
#plt.plot(accuracy_r2unet,color='blue')
#plt.plot(accuracy_attn_unet,color='orange')
plt.plot(accuracy_multi_res_unet,color='brown', linestyle='-.', dashes=(5, 1), linewidth=3.0)
plt.plot(accuracy_UNet,color='black', linestyle=':', linewidth=3.0)
#plt.plot(accuracy_attn_1_proposed,color='red')
plt.plot(accuracy_ms_proposed,color='red', linestyle='-', linewidth=3.0)
#plt.plot(accuracy_orunet,color='purple')
plt.xticks(fontsize=34)
plt.yticks(fontsize=35)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['MultiResUnet','Mod UNet', 'Proposed DRRMSAN MS'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.53, 0.67))
plt.savefig('LUNGS_accuracy_coef.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-1e0f66145e49> in <module>
#      37
#      38 accuracy_ms_proposed = []
# ---> 39 for item in drrmsan_ms['activation_116_accuracy']:
#      40     accuracy_ms_proposed.append(drrmsan_ms['activation_116_accuracy'][item])
#      41
#
# KeyError: 'activation_116_accuracy'

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""
print("Accuracy for attnR2Unet = ",accuracy_attnR2Unet[-1])
print("Accuracy for r2unet = ",accuracy_r2unet[-1])
print("Accuracy for attn_unet = ",accuracy_attn_unet[-1])
print("Accuracy for multi_res_unet = ",accuracy_multi_res_unet[-1])
print("Accuracy for UNet = ",accuracy_UNet[-1])
print("Accuracy for orunet = ",accuracy_orunet[-1])
print("Accuracy for DRRMSAN MS = ",accuracy_ms_proposed[-1])
# Out:
# Accuracy for attnR2Unet =  0.1493252814
# Accuracy for r2unet =  0.1278764158
# Accuracy for attn_unet =  0.0718986765
# Accuracy for multi_res_unet =  0.9950249195
# Accuracy for UNet =  0.9968813658
# Accuracy for orunet =  0.1307765096
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-a36b3810f476> in <module>
#      13 print("Accuracy for UNet = ",accuracy_UNet[-1])
#      14 print("Accuracy for orunet = ",accuracy_orunet[-1])
# ---> 15 print("Accuracy for DRRMSAN MS = ",accuracy_ms_proposed[-1])
#
# IndexError: list index out of range

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

recall_attnR2Unet = []
for item in attnR2Unet['recall']:
    recall_attnR2Unet.append(attnR2Unet['recall'][item])

recall_r2unet = []
for item in r2unet['recall']:
    recall_r2unet.append(r2unet['recall'][item])

recall_attn_unet = []
for item in attn_unet['recall']:
    recall_attn_unet.append(attn_unet['recall'][item])

recall_multi_res_unet = []
for item in multi_res_unet['recall']:
    recall_multi_res_unet.append(multi_res_unet['recall'][item])

recall_UNet = []
for item in UNet['recall']:
    recall_UNet.append(UNet['recall'][item])
    
recall_orunet = []
for item in orunet['recall']:
    recall_orunet.append(orunet['recall'][item])



recall_ms_proposed = []
for item in drrmsan_ms['activation_116_recall']:
    recall_ms_proposed.append(drrmsan_ms['activation_116_recall'][item])

plt.figure(figsize=(12,6))
plt.title('Recall for CHEST dataset', fontsize=35, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(recall_attnR2Unet,color='green', linestyle='-.', dashes=(5, 1), linewidth=3.0)
plt.plot(recall_r2unet,color='blue', linestyle='--', dashes=(5, 1),  linewidth=3.0)
plt.plot(recall_attn_unet,color='orange', linestyle='-', dashes=(5, 1),  linewidth=3.0)
plt.plot(recall_multi_res_unet,color='brown', linewidth=3.0)
plt.plot(recall_UNet,color='black', linewidth=3.0)
plt.plot(recall_orunet,color='purple', linewidth=3.0)
# plt.plot(recall_attn_1_proposed,color='red')
plt.plot(recall_ms_proposed,color='red', linewidth=3.0)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
lgd = plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed DRRMSAN MS'],
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.52, 0.33))
plt.savefig('CHEST_recall.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-bd4c47d5e34f> in <module>
#      35
#      36 recall_ms_proposed = []
# ---> 37 for item in drrmsan_ms['activation_116_recall']:
#      38     recall_ms_proposed.append(drrmsan_ms['activation_116_recall'][item])
#      39
#
# KeyError: 'activation_116_recall'

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""
print("Recall for attnR2Unet = ",recall_attnR2Unet[-1])
print("Recall for r2unet = ",recall_r2unet[-1])
print("Recall for attn_unet = ",recall_attn_unet[-1])
print("Recall for multi_res_unet = ",recall_multi_res_unet[-1])
print("Recall for UNet = ",recall_UNet[-1])
print("Recall for orunet = ",recall_orunet[-1])
print("Recall for DRRMSAN MS = ",recall_ms_proposed[-1])
# Out:
# Recall for attnR2Unet =  0.9960481524
# Recall for r2unet =  0.9957942963
# Recall for attn_unet =  0.9850051999
# Recall for multi_res_unet =  0.9974578023
# Recall for UNet =  0.9938154817
# Recall for orunet =  0.9798591137
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-b51fa49f857c> in <module>
#      13 print("Recall for UNet = ",recall_UNet[-1])
#      14 print("Recall for orunet = ",recall_orunet[-1])
# ---> 15 print("Recall for DRRMSAN MS = ",recall_ms_proposed[-1])
#
# IndexError: list index out of range

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

precision_attnR2Unet = []
for item in attnR2Unet['precision']:
    precision_attnR2Unet.append(attnR2Unet['precision'][item])

precision_r2unet = []
for item in r2unet['precision']:
    precision_r2unet.append(r2unet['precision'][item])

precision_attn_unet = []
for item in attn_unet['precision']:
    precision_attn_unet.append(attn_unet['precision'][item])

precision_multi_res_unet = []
for item in multi_res_unet['precision']:
    precision_multi_res_unet.append(multi_res_unet['precision'][item])

precision_UNet = []
for item in UNet['precision']:
    precision_UNet.append(UNet['precision'][item])
    
precision_orunet = []
for item in orunet['precision']:
    precision_orunet.append(orunet['precision'][item])

precision_ms_proposed = []
for item in drrmsan_ms['activation_116_recall']:
    precision_ms_proposed.append(drrmsan_ms['activation_116_recall'][item])

plt.figure(figsize=(12,6))
plt.title('Precision for CHEST dataset', fontsize=35, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(precision_attnR2Unet,color='green', linestyle='-.', dashes=(5, 1), linewidth=3.0)
plt.plot(precision_r2unet,color='blue', linestyle='--', dashes=(5, 1),  linewidth=3.0)
plt.plot(precision_attn_unet,color='orange', linestyle=':',  linewidth=3.0)
plt.plot(precision_multi_res_unet,color='brown', linestyle='-', linewidth=3.0)
plt.plot(precision_UNet,color='black',  linewidth=3.0)
plt.plot(precision_orunet,color='purple',  linewidth=3.0)
#plt.plot(precision_attn_1_proposed,color='red')
plt.plot(precision_ms_proposed,color='red',  linewidth=3.0)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
lgd = plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed DRRMSAN MS'],
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.53, 0.32))
plt.savefig('CHEST_precision.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-b9d2cd12f039> in <module>
#      33
#      34 precision_ms_proposed = []
# ---> 35 for item in drrmsan_ms['activation_116_recall']:
#      36     precision_ms_proposed.append(drrmsan_ms['activation_116_recall'][item])
#      37
#
# KeyError: 'activation_116_recall'

# %%
print("precision for attnR2Unet = ",precision_attnR2Unet[-1])
print("precision for r2unet = ",precision_r2unet[-1])
print("precision for attn_unet = ",precision_attn_unet[-1])
print("precision for multi_res_unet = ",precision_multi_res_unet[-1])
print("precision for UNet = ",precision_UNet[-1])
print("precision for orunet = ",precision_orunet[-1])
print("precision for DRRMSAN MS = ",precision_ms_proposed[-1])
# Out:
# precision for attnR2Unet =  0.996105969
# precision for r2unet =  0.99586761
# precision for attn_unet =  0.9856010675
# precision for multi_res_unet =  0.9833167791
# precision for UNet =  0.9939816594
# precision for orunet =  0.9800193906
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-198d33ca70a2> in <module>
#       5 print("precision for UNet = ",precision_UNet[-1])
#       6 print("precision for orunet = ",precision_orunet[-1])
# ----> 7 print("precision for DRRMSAN MS = ",precision_ms_proposed[-1])
#
# IndexError: list index out of range

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

jacard_attnR2Unet = []
for item in attnR2Unet['jacard']:
    jacard_attnR2Unet.append(attnR2Unet['jacard'][item])

jacard_r2unet = []
for item in r2unet['jacard']:
    jacard_r2unet.append(r2unet['jacard'][item])

jacard_attn_unet = []
for item in attn_unet['jacard']:
    jacard_attn_unet.append(attn_unet['jacard'][item])

jacard_multi_res_unet = []
for item in multi_res_unet['jacard']:
    jacard_multi_res_unet.append(multi_res_unet['jacard'][item])

jacard_UNet = []
for item in UNet['jacard']:
    jacard_UNet.append(UNet['jacard'][item])
    
jacard_orunet = []
for item in orunet['jacard']:
    jacard_orunet.append(orunet['jacard'][item])

jacard_ms_proposed = []
for item in drrmsan_ms['side_8_jacard']:
    jacard_ms_proposed.append(drrmsan_ms['side_8_jacard'][item])
    
plt.figure(figsize=(12,6))
plt.title('Jaccard for LUNGS dataset', fontsize=35, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(jacard_attnR2Unet,color='green', linestyle='-.', dashes=(5, 1), linewidth=3.0)
plt.plot(jacard_r2unet,color='blue', linestyle='--', dashes=(5, 1),  linewidth=3.0)
plt.plot(jacard_attn_unet,color='orange', linestyle=':',  linewidth=3.0)
plt.plot(jacard_multi_res_unet,color='brown', linewidth=3.0)
plt.plot(jacard_UNet,color='black', linewidth=3.0)
plt.plot(jacard_orunet,color='purple', linewidth=3.0)
#plt.plot(jacard_attn_1_proposed,color='red')
plt.plot(jacard_ms_proposed,color='red', linewidth=3.0)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)

lgd = plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed DRRMSAN MS'],
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.52, 0.32))
plt.savefig('LUNGS_jacard.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('LUNGS_jacard.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("jacard for attnR2Unet = ",jacard_attnR2Unet[-1])
print("jacard for r2unet = ",jacard_r2unet[-1])
print("jacard for attn_unet = ",jacard_attn_unet[-1])
print("jacard for multi_res_unet = ",jacard_multi_res_unet[-1])
print("jacard for UNet = ",jacard_UNet[-1])
print("jacard for orunet = ",jacard_orunet[-1])
print("jacard for Proposed DRRMSAN MS = ",jacard_ms_proposed[-1])
# Out:
# jacard for attnR2Unet =  0.9883076549
# jacard for r2unet =  0.9880087972
# jacard for attn_unet =  0.9586003423
# jacard for multi_res_unet =  0.4130888879
# jacard for UNet =  0.8973905444
# jacard for orunet =  0.942604959
# jacard for Proposed DRRMSAN MS =  0.9626946449

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

loss_attnR2Unet = []
for item in attnR2Unet['loss']:
    loss_attnR2Unet.append(attnR2Unet['loss'][item])

loss_r2unet = []
for item in r2unet['loss']:
    loss_r2unet.append(r2unet['loss'][item])

loss_attn_unet = []
for item in attn_unet['loss']:
    loss_attn_unet.append(attn_unet['loss'][item])

loss_multi_res_unet = []
for item in multi_res_unet['loss']:
    loss_multi_res_unet.append(multi_res_unet['loss'][item])

loss_UNet = []
for item in UNet['loss']:
    loss_UNet.append(UNet['loss'][item])
    
loss_orunet = []
for item in orunet['loss']:
    loss_orunet.append(orunet['loss'][item])



loss_ms_proposed = []
for item in drrmsan_ms['side_8_loss']:
    loss_ms_proposed.append(drrmsan_ms['side_8_loss'][item])
    
plt.figure(figsize=(12,6))
plt.title('Loss for CHEST dataset', fontsize=35, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(loss_attnR2Unet,color='green', linestyle='--', dashes=(5, 1), linewidth=3.0)
plt.plot(loss_r2unet,color='blue',linestyle='-.', dashes=(5, 1), linewidth=3.0)
plt.plot(loss_attn_unet,color='orange',linestyle=':', dashes=(5, 1), linewidth=3.0)
plt.plot(loss_multi_res_unet,color='brown', linewidth=3.0)
plt.plot(loss_UNet,color='black', linewidth=3.0)
plt.plot(loss_orunet,color='purple', linewidth=3.0)
#plt.plot(loss_attn_1_proposed,color='red')
plt.plot(loss_ms_proposed,color='red',  linewidth=3.0)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
lgd = plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed DRRMSAN MS'],
           loc="upper right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.52, 1.025))
plt.savefig('CHEST_loss.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("loss for attnR2Unet = ",loss_attnR2Unet[-1])
print("loss for r2unet = ",loss_r2unet[-1])
print("loss for attn_unet = ",loss_attn_unet[-1])
print("loss for multi_res_unet = ",loss_multi_res_unet[-1])
print("loss for UNet = ",loss_UNet[-1])
print("loss for orunet = ",loss_orunet[-1])
print("loss for DRRMSAN MS = ",loss_ms_proposed[-1])
# Out:
# loss for attnR2Unet =  0.0048112166
# loss for r2unet =  0.005060988
# loss for attn_unet =  0.0173636917
# loss for multi_res_unet =  0.361161381
# loss for UNet =  0.0300920941
# loss for orunet =  0.0240132455
# loss for DRRMSAN MS =  0.0166409165

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

dice_coef_attnR2Unet = []
for item in attnR2Unet['dice_coef']:
    dice_coef_attnR2Unet.append(attnR2Unet['dice_coef'][item])

dice_coef_r2unet = []
for item in r2unet['dice_coef']:
    dice_coef_r2unet.append(r2unet['dice_coef'][item])

dice_coef_attn_unet = []
for item in attn_unet['dice_coef']:
    dice_coef_attn_unet.append(attn_unet['dice_coef'][item])

dice_coef_multi_res_unet = []
for item in multi_res_unet['dice_coef']:
    dice_coef_multi_res_unet.append(multi_res_unet['dice_coef'][item])

dice_coef_UNet = []
for item in UNet['dice_coef']:
    dice_coef_UNet.append(UNet['dice_coef'][item])
    
dice_coef_orunet = []
for item in orunet['dice_coef']:
    dice_coef_orunet.append(orunet['dice_coef'][item])


dice_coef_ms_proposed = []
for item in drrmsan_ms['side_8_dice_coef']:
    dice_coef_ms_proposed.append(drrmsan_ms['side_8_dice_coef'][item])

plt.figure(figsize=(12,6))
plt.title('Dice Coeffficient for CHEST dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(dice_coef_attnR2Unet,color='green', linestyle='-.', dashes=(5, 1), linewidth=3.0)
plt.plot(dice_coef_r2unet,color='blue', linestyle='--', dashes=(5, 1),  linewidth=3.0)
plt.plot(dice_coef_attn_unet,color='orange', linestyle='-', linewidth=3.0)
plt.plot(dice_coef_multi_res_unet,color='brown', linewidth=3.0)
plt.plot(dice_coef_UNet,color='black', linewidth=3.0)
plt.plot(dice_coef_orunet,color='purple', linestyle=':',  linewidth=3.0)
#plt.plot(dice_coef_attn_1_proposed,color='red')
plt.plot(dice_coef_ms_proposed,color='red', linewidth=3.0)
plt.xticks(fontsize=25, fontname = 'DejaVu Serif')
plt.yticks(fontsize=25, fontname = 'DejaVu Serif')
lgd = plt.legend(['Attention R2Unet','R2Unet','Attention Unet','MultiResUnet','Modified UNet','UNet','MSAN-1'],
           loc="lower right", prop={'family':'DejaVu Serif', 'size':25}, bbox_to_anchor=(1.50, 0.18))
plt.savefig('CHEST_dice_coef.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("dice_coef for attnR2Unet = ",dice_coef_attnR2Unet[-1])
print("dice_coef for r2unet = ",dice_coef_r2unet[-1])
print("dice_coef for attn_unet = ",dice_coef_attn_unet[-1])
print("dice_coef for multi_res_unet = ",dice_coef_multi_res_unet[-1])
print("dice_coef for UNet = ",dice_coef_UNet[-1])
print("dice_coef for orunet = ",dice_coef_orunet[-1])
print("dice_coef for DRRMSAN MS = ",dice_coef_ms_proposed[-1])
# Out:
# dice_coef for attnR2Unet =  0.9941186905
# dice_coef for r2unet =  0.9939669371
# dice_coef for attn_unet =  0.9788571596
# dice_coef for multi_res_unet =  0.5828898549
# dice_coef for UNet =  0.9453220963
# dice_coef for orunet =  0.9704326987
# dice_coef for DRRMSAN MS =  0.9840777516
